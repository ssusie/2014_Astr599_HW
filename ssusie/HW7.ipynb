# %%
from astroML.datasets import fetch_rrlyrae_combined
from sklearn.cross_validation import train_test_split

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
X, y = fetch_rrlyrae_combined()

# For now, we'll only fit the first two colors
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
N_plot = 5000
plt.scatter(X[-N_plot:, 0], X[-N_plot:, 1], c=y[-N_plot:],
            edgecolors='none')
plt.xlabel('u-g color')
plt.ylabel('g-r color');

# %% [markdown]
# #Gaussian

# %%
from sklearn.naive_bayes  import GaussianNB
clf = GaussianNB()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %%
print(np.sum(y_pred == y_test))
print(np.sum(y_pred != y_test))
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred,
                            target_names=['MS star', 'RR Lyrae']))
# Out:
# 22780
# 506
#              precision    recall  f1-score   support
#
#     MS star       1.00      0.98      0.99     23172
#    RR Lyrae       0.17      0.86      0.28       114
#
# avg / total       1.00      0.98      0.99     23286

# %% [markdown]
# #LDA

# %%
from sklearn.lda import LDA
clf = LDA()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(np.sum(y_pred == y_test))
print(np.sum(y_pred != y_test))
# Out:
# 22838
# 448

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred,
                            target_names=['MS star', 'RR Lyrae']))
# Out:
#              precision    recall  f1-score   support
#
#     MS star       1.00      0.98      0.99     23172
#    RR Lyrae       0.16      0.68      0.26       114
#
# avg / total       0.99      0.98      0.99     23286

# %% [markdown]
# #SVC

# %%
from sklearn.svm import SVC
clf = SVC(kernel='rbf')
clf.fit(X_train[::8], y_train[::8])
y_pred = clf.predict(X_test)

# %%
print(np.sum(y_pred == y_test))
print(np.sum(y_pred != y_test))
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred,
                            target_names=['MS star', 'RR Lyrae']))
# Out:
# 23172
# 114
#              precision    recall  f1-score   support
#
#     MS star       1.00      1.00      1.00     23172
#    RR Lyrae       0.00      0.00      0.00       114
#
# avg / total       0.99      1.00      0.99     23286
# /Users/susie/anaconda/lib/python2.7/site-packages/sklearn/metrics/metrics.py:1905: UserWarning: The sum of true positives and false positives are equal to zero for some labels. Precision is ill defined for those labels [ 1.]. The precision and recall are equal to zero for some labels. fbeta_score is ill defined for those labels [ 1.].
#   average=None)

# %% [markdown]
# #SVC with kernel=rbf

# %%
from sklearn.svm import SVC
clf = SVC(kernel='rbf')
clf.fit(X_train[::2], y_train[::2])
y_pred = clf.predict(X_test)

# %%
print(np.sum(y_pred == y_test))
print(np.sum(y_pred != y_test))
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred,
                            target_names=['MS star', 'RR Lyrae']))
# Out:
# 23172
# 114
#              precision    recall  f1-score   support
#
#     MS star       1.00      1.00      1.00     23172
#    RR Lyrae       0.00      0.00      0.00       114
#
# avg / total       0.99      1.00      0.99     23286

# %% [markdown]
# #RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()
clf.fit(X_train[::2], y_train[::2])
y_pred = clf.predict(X_test)

# %%
print(np.sum(y_pred == y_test))
print(np.sum(y_pred != y_test))
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred,
                            target_names=['MS star', 'RR Lyrae']))
# Out:
# 23209
# 77
#              precision    recall  f1-score   support
#
#     MS star       1.00      1.00      1.00     23172
#    RR Lyrae       0.76      0.47      0.58       114
#
# avg / total       1.00      1.00      1.00     23286

# %% [markdown]
# The Best I could get for RR Lyrae error was $precision =0.76
# $ ,  $recall=0.47$ with taking every other element from training set.

# %% [markdown]
# #Exercise 2

# %%
from astroML.datasets import fetch_sdss_specgals

# %%
data = fetch_sdss_specgals()

# put magnitudes in a matrix
X = np.vstack([data['modelMag_%s' % f] for f in 'ugriz']).T
y = data['z']

# Split into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
from sklearn.linear_model import LinearRegression
est = LinearRegression()
est.fit(X_train, y_train)
y_pred = est.predict(X_test)

# %%
plt.plot(y_test, y_pred, ',k')
plt.plot([0, 1], [0, 1], ':k')
plt.xlim(0, 0.6)
plt.ylim(0, 0.6)
# Out:
# (0, 0.6)

# %%
rms = np.sqrt(np.mean((y_test - y_pred) ** 2))
print(rms)
# Out:
# 0.0328488711638

# %% [markdown]
# #Kneighbors

# %%
from sklearn.neighbors import KNeighborsRegressor
est = KNeighborsRegressor()
est.fit(X_train, y_train)
y_pred = est.predict(X_test)

plt.plot(y_test, y_pred, ',k')
plt.plot([0, 1], [0, 1], ':k')
plt.xlim(0, 0.6)
plt.ylim(0, 0.6)

rms = np.sqrt(np.mean((y_test - y_pred) ** 2))
print(rms)
# Out:
# 0.0234903

# %% [markdown]
# #SVR

# %%
from sklearn.svm import SVR 
est = SVR()
est.fit(X_train[::3], y_train[::3])
y_pred = est.predict(X_test)

plt.plot(y_test, y_pred, ',k')
plt.plot([0, 1], [0, 1], ':k')
plt.xlim(0, 0.6)
plt.ylim(0, 0.6)

rms = np.sqrt(np.mean((y_test - y_pred) ** 2))
print(rms)
# Out:
# 0.0401147512398

# %% [markdown]
# #RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor 
est = RandomForestRegressor() 
est.fit(X_train[::2], y_train[::2])
y_pred = est.predict(X_test)

plt.plot(y_test, y_pred, ',k')
plt.plot([0, 1], [0, 1], ':k')
plt.xlim(0, 0.6)
plt.ylim(0, 0.6)

rms = np.sqrt(np.mean((y_test - y_pred) ** 2))
print(rms)
# Out:
# 0.0234083790421

# %% [markdown]
# #GradientBoostingRegressor

# %%
from sklearn.ensemble import GradientBoostingRegressor
est = GradientBoostingRegressor() 
est.fit(X_train[::5], y_train[::5])
y_pred = est.predict(X_test)

plt.plot(y_test, y_pred, ',k')
plt.plot([0, 1], [0, 1], ':k')
plt.xlim(0, 0.6)
plt.ylim(0, 0.6)

rms = np.sqrt(np.mean((y_test - y_pred) ** 2))
print(rms)
# Out:
# 0.0285235994732

# %% [markdown]
# The best I could get for rms error was 0.0234083790421 using random forest regressor.
